# %% [markdown]
# # Semi Finals of CS 3103
# by Jerson Paul Leones

# %%
path = './2017.arff'

# %% [markdown]
# ### Data Processiing

# %%
def read_file(file_path) -> list:
    with open(file_path) as f:
        contents = f.readlines()

    attr = contents[2 : contents.index("@data\n") - 1]
    data = contents[contents.index("@data\n") + 1 :]

    return attr, data

attr, data  = read_file(path)

print(attr)
print(data)
# Out:
# ['@attribute Num numeric\n', "@attribute Country {Hungary,Poland,'Czech Republic',Slovakia}\n", '@attribute X1 string\n', '@attribute X2 string\n', '@attribute X3 string\n', '@attribute X4 string\n', '@attribute X5 string\n', '@attribute X6 string\n', '@attribute X7 string\n', '@attribute X8 string\n', '@attribute X9 string\n', '@attribute X10 string\n', '@attribute X11 string\n', '@attribute X12 string\n', '@attribute X13 string\n', '@attribute X14 string\n', '@attribute X15 string\n', '@attribute X16 string\n', '@attribute X17 string\n', '@attribute X18 string\n', '@attribute X19 string\n', '@attribute X20 string\n', '@attribute X21 string\n', '@attribute X22 string\n', '@attribute X23 string\n', '@attribute X24 string\n', '@attribute X25 string\n', '@attribute X26 string\n', '@attribute X27 string\n', '@attribute X28 string\n', '@attribute X29 string\n', '@attribute X30 string\n', '@attribute X31 string\n', '@attribute X32 string\n', '@attribute X33 string\n', '@attribute X34 stri
# ...

# %% [markdown]
# ### Data Parsing

# %%
def parse_data(attr, data) -> list:
    obj_list = []
    for item in data:
        vals = item.strip().split(",")
        for key, val in zip(attr, vals):
            dct = {key: val if val != "m" else None}
            obj_list.append(dct)

    return obj_list

parsed_data = parse_data(attr, data)
# Out:
# [{'@attribute Num numeric\n': '10'}, {"@attribute Country {Hungary,Poland,'Czech Republic',Slovakia}\n": 'Hungary'}, {'@attribute X1 string\n': '0.14'}, {'@attribute X2 string\n': '0.53'}, {'@attribute X3 string\n': '0.19'}, {'@attribute X4 string\n': '1.41'}, {'@attribute X5 string\n': '0.33'}, {'@attribute X6 string\n': '0.14'}, {'@attribute X7 string\n': '0.89'}, {'@attribute X8 string\n': '1.08'}, {'@attribute X9 string\n': '0.47'}, {'@attribute X10 string\n': '0.17'}, {'@attribute X11 string\n': '0.31'}, {'@attribute X12 string\n': '0.13'}, {'@attribute X13 string\n': '0.15'}, {'@attribute X14 string\n': '0.27'}, {'@attribute X15 string\n': '1.89'}, {'@attribute X16 string\n': '0.26'}, {'@attribute X17 string\n': '0.13'}, {'@attribute X18 string\n': '0.14'}, {'@attribute X19 string\n': '0.13'}, {'@attribute X20 string\n': '0.14'}, {'@attribute X21 string\n': '0.27'}, {'@attribute X22 string\n': '-4.59'}, {'@attribute X23 string\n': '0.52'}, {'@attribute X24 string\n': '6.24'}, {
# ...

# %% [markdown]
# ### Principal Component Analysis (PCA) from Scratch

# %% [markdown]
# ### Principal Component Analyysis with the use of libraries
